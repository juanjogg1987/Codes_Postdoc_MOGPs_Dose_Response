# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

import warnings
warnings.filterwarnings("ignore")

import os

# _FOLDER = "/home/ac1jjgg/MOGP_GPyTorch/FiveCancersDataSet/"
_FOLDER = "/home/juanjo/Work_Postdoc/my_codes_postdoc/GPy_Models/Codes_For_GDSC2/"
"""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""
"""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""
df_Feature_Names_Melanoma = pd.read_csv(_FOLDER + "Best_Model_MelanomaGDSC2_GPy_ExactMOGP/Name_Features_MelanomaGDSC2.csv")

# %%
List_Names_Melanoma = list(df_Feature_Names_Melanoma.values[:,1])

# %%
List_Names_Melanoma
# Out:
# ['AFF4_mut',
#  'AHCTF1_mut',
#  'AKAP9_mut',
#  'ANK3_mut',
#  'APC_mut',
#  'ARFGAP3_mut',
#  'ARHGAP29_mut',
#  'ARID1A_mut',
#  'ARID1B_mut',
#  'ARID2_mut',
#  'ARID4A_mut',
#  'ASPM_mut',
#  'ASXL2_mut',
#  'ATM_mut',
#  'B2M_mut',
#  'BAP1_mut',
#  'BAZ2B_mut',
#  'BPTF_mut',
#  'BRAF_mut',
#  'BRCA2_mut',
#  'BRWD1_mut',
#  'CDC27_mut',
#  'CDKN2A_mut',
#  'CEP290_mut',
#  'CHEK2_mut',
#  'CLASP2_mut',
#  'CLSPN_mut',
#  'CREBBP_mut',
#  'CTCF_mut',
#  'CTNNB1_mut',
#  'CUL2_mut',
#  'CUX1_mut',
#  'DHX15_mut',
#  'ELF1_mut',
#  'EP300_mut',
#  'EZH2_mut',
#  'FAM123B_mut',
#  'FGFR2_mut',
#  'GNA11_mut',
#  'HDAC9_mut',
#  'HRAS_mut',
#  'INPP4A_mut',
#  'INPPL1_mut',
#  'KDM6A_mut',
#  'LAMA2_mut',
#  'LPHN2_mut',
#  'LRP6_mut',
#  'MACF1_mut',
#  'MAGI2_mut',
#  'MAP2K1_mut',
#  'MAP3K4_mut',
#  'MCM8_mut',
#  'MECOM_mut',
#  'MGA_mut',
#  'MLL2_mut',
#  'MLL3_mut',
#  'MYH11_mut',
#  'MYH14_mut',
#  'MYH9_mut',
#  'NCOR1_mut',
#  'NF1_mut',
#  'NRAS_mut',
#  'PABPC3_mut',
#  'PCDH18_mut',
#  'PHLPP1_mut',
#  'PIK3R1_mut',
#  'PLCB1_mut',
#  'PLXNA1_mut',
#  'PSIP1_mut',
#  'PTEN_mut',
#  'RAC1_mut',
#  'RB1_mut',
#  'ROBO2_mut',
#  'RPL5_mut',
#  'SEC31A_mut',
#  'SETD2_mut',
#  'SMARCA1_mut',
#  'SMARCA4_mut',
#  'SOS2_mut',
#  'SRGAP1_mut',
#  'STAG1_mut',
#  'STAG2_mut',
#  'STIP1_mut',
#  'STK11_mut',
#  'TAF1_mut',
#  'TAOK1_mut',
#  'TP53_mut',
#  'TSC1_mut',
#  'WHSC1_mut',
#  'WHSC1L1_mut',
#  'WT1_mut',
#  'ZFHX3_mut',
#  'ZMYM2_mut',
#  'ZNF292_mut',
#  'ZNF638_mut',
#  'gain:cnaPANCAN1 (CCNE1)',
#  'loss:cnaPANCAN2 (STK11)',
#  'loss:cnaPANCAN6',
#  'loss:cnaPANCAN8',
#  'loss:cnaPANCAN15',
#  'gain:cnaPANCAN18',
#  'loss:cnaPANCAN20',
#  'loss:cnaPANCAN21',
#  'loss:cnaPANCAN22',
#  'loss:cnaPANCAN23 (SMAD4)',
#  'loss:cnaPANCAN24',
#  'loss:cnaPANCAN25',
#  'loss:cnaPANCAN26',
#  'gain:cnaPANCAN28 (CUL2,EPC1)',
#  'loss:cnaPANCAN30 (LARP4B)',
#  'loss:cnaPANCAN31',
#  'loss:cnaPANCAN32',
#  'loss:cnaPANCAN33',
#  'loss:cnaPANCAN34',
#  'loss:cnaPANCAN35 (CUL2)',
#  'loss:cnaPANCAN36 (RET)',
#  'loss:cnaPANCAN37',
#  'loss:cnaPANCAN38',
#  'loss:cnaPANCAN39',
#  'loss:cnaPANCAN40',
#  'loss:cnaPANCAN41',
#  'loss:cnaPANCAN42 (ANK3)',
#  'loss:cnaPANCAN43',
#  'loss:cnaPANCAN44 (BMPR1A,FAS,PTEN)',
#  'loss:cnaPANCAN45',
#  'loss:cnaPANCAN46',
#  'loss:cnaPANCAN47',
#  'loss:cnaPANCAN48',
#  'loss:cnaPANCAN49',
#  'loss:cnaPANCAN50',
#  'loss:cnaPANCAN51',
#  'loss:cnaPANCAN52',
#  'loss:cnaPANCAN53',
#  'loss:cnaPANCAN54',
#  'loss:cnaPANCAN55',
#  'gain:cnaPANCAN57 (CAT)',
#  'gain:cnaPANCAN58',
#  'gain:cnaPANCAN59 (CCND1,CTTN)',
#  'gain:cnaPANCAN60',
#  'gain:cnaPANCAN61',
#  'loss:cnaPANCAN62 (HRAS,IRF7)',
#  'loss:cnaPANCAN63',
#  'loss:cnaPANCAN64',
#  'loss:cnaPANCAN65',
#  'loss:cnaPANCAN66',
#  'loss:cnaPANCAN67',
#  'loss:cnaPANCAN68',
#  'loss:cnaPANCAN69',
#  'loss:cnaPANCAN70',
#  'loss:cnaPANCAN71 (EXT2)',
#  'loss:cnaPANCAN72',
#  'loss:cnaPANCAN73',
#  'loss:cnaPANCAN74',
#  'loss:cnaPANCAN75 (MED17)',
#  'loss:cnaPANCAN76',
#  'loss:cnaPANCAN77 (CASP1)',
#  'loss:cnaPANCAN78 (CASP1)',
#  'loss:cnaPANCAN79',
#  'loss:cnaPANCAN80 (SDHD)',
#  'loss:cnaPANCAN81',
#  'loss:cnaPANCAN82',
#  'gain:cnaPANCAN84 (FGFR1,WHSC1L1)',
#  'gain:cnaPANCAN89 (RAD21)',
#  'gain:cnaPANCAN90',
#  'gain:cnaPANCAN91 (MYC)',
#  'loss:cnaPANCAN92',
#  'loss:cnaPANCAN93',
#  'loss:cnaPANCAN94',
#  'loss:cnaPANCAN95',
#  'loss:cnaPANCAN96',
#  'loss:cnaPANCAN97',
#  'loss:cnaPANCAN98',
#  'loss:cnaPANCAN99 (SOX17)',
#  'loss:cnaPANCAN101',
#  'gain:cnaPANCAN108 (CHD9,CYLD)',
#  'loss:cnaPANCAN110',
#  'loss:cnaPANCAN113',
#  'loss:cnaPANCAN116',
#  'loss:cnaPANCAN117 (CHD9,CNOT1,CYLD,MMP2,NUP93)',
#  'loss:cnaPANCAN118 (ZFHX3)',
#  'loss:cnaPANCAN119',
#  'loss:cnaPANCAN120',
#  'gain:cnaPANCAN121 (ACTB,CARD11,PMS2,RAC1)',
#  'gain:cnaPANCAN122 (AHR,HDAC9)',
#  'gain:cnaPANCAN123',
#  'gain:cnaPANCAN124 (EGFR)',
#  'gain:cnaPANCAN125',
#  'gain:cnaPANCAN126',
#  'gain:cnaPANCAN127 (AKAP9)',
#  'gain:cnaPANCAN128',
#  'gain:cnaPANCAN129 (MET)',
#  'gain:cnaPANCAN130 (RHEB)',
#  'loss:cnaPANCAN137 (POT1)',
#  'loss:cnaPANCAN144 (BNC2,CDKN2A,JAK2,PSIP1)',
#  'loss:cnaPANCAN145 (FANCG,PAX5)',
#  'loss:cnaPANCAN146 (GNAQ,NTRK2,PCSK5,TJP2)',
#  'loss:cnaPANCAN147',
#  'loss:cnaPANCAN148',
#  'loss:cnaPANCAN149',
#  'loss:cnaPANCAN150 (PTGS1)',
#  'loss:cnaPANCAN151',
#  'loss:cnaPANCAN152',
#  'loss:cnaPANCAN153 (ABL1)',
#  'loss:cnaPANCAN154',
#  'loss:cnaPANCAN155',
#  'loss:cnaPANCAN156',
#  'loss:cnaPANCAN157',
#  'loss:cnaPANCAN158',
#  'loss:cnaPANCAN159',
#  'loss:cnaPANCAN160',
#  'loss:cnaPANCAN161 (NOTCH1)',
#  'loss:cnaPANCAN162',
#  'gain:cnaPANCAN163 (CHD4,WNK1)',
#  'gain:cnaPANCAN164 (KRAS)',
#  'gain:cnaPANCAN165 (CDK4)',
#  'gain:cnaPANCAN166 (MDM2,NUP107,SRGAP1)',
#  'loss:cnaPANCAN167',
#  'loss:cnaPANCAN168',
#  'loss:cnaPANCAN169',
#  'loss:cnaPANCAN170',
#  'loss:cnaPANCAN171',
#  'loss:cnaPANCAN172',
#  'loss:cnaPANCAN173',
#  'loss:cnaPANCAN174',
#  'loss:cnaPANCAN175',
#  'gain:cnaPANCAN176 (CCT5,TERT,TRIO)',
#  'gain:cnaPANCAN177 (IL7R)',
#  'gain:cnaPANCAN178',
#  'loss:cnaPANCAN181',
#  'gain:cnaPANCAN190 (FGFR3,WHSC1)',
#  'loss:cnaPANCAN193',
#  'loss:cnaPANCAN194 (FGFR3)',
#  'loss:cnaPANCAN195',
#  'loss:cnaPANCAN196',
#  'loss:cnaPANCAN197',
#  'loss:cnaPANCAN198',
#  'loss:cnaPANCAN199',
#  'loss:cnaPANCAN200',
#  'loss:cnaPANCAN201',
#  'loss:cnaPANCAN202',
#  'loss:cnaPANCAN203',
#  'loss:cnaPANCAN204',
#  'loss:cnaPANCAN205',
#  'loss:cnaPANCAN206',
#  'loss:cnaPANCAN207',
#  'loss:cnaPANCAN208 (PCDH18)',
#  'loss:cnaPANCAN209',
#  'loss:cnaPANCAN210 (FAT1,IRF2)',
#  'gain:cnaPANCAN211',
#  'gain:cnaPANCAN214',
#  'loss:cnaPANCAN217',
#  'loss:cnaPANCAN218',
#  'loss:cnaPANCAN219',
#  'loss:cnaPANCAN220 (HIST1H3B)',
#  'loss:cnaPANCAN221',
#  'loss:cnaPANCAN222',
#  'loss:cnaPANCAN223',
#  'loss:cnaPANCAN224',
#  'loss:cnaPANCAN225',
#  'loss:cnaPANCAN226',
#  'loss:cnaPANCAN227',
#  'loss:cnaPANCAN228',
#  'loss:cnaPANCAN229',
#  'loss:cnaPANCAN230 (SYNCRIP,ZNF292)',
#  'loss:cnaPANCAN231',
#  'loss:cnaPANCAN232',
#  'loss:cnaPANCAN233',
#  'loss:cnaPANCAN234',
#  'loss:cnaPANCAN235 (ARID1B,MAP3K4,MLLT4)',
#  'gain:cnaPANCAN239 (FOXP1,MITF)',
#  'gain:cnaPANCAN240',
#  'gain:cnaPANCAN241 (NCK1,STAG1)',
#  'gain:cnaPANCAN242 (PIK3CB)',
#  'gain:cnaPANCAN243',
#  'gain:cnaPANCAN244',
#  'gain:cnaPANCAN245 (MECOM)',
#  'gain:cnaPANCAN246 (SOX2)',
#  'gain:cnaPANCAN247',
#  'gain:cnaPANCAN248 (EIF4A2,RFC4)',
#  'loss:cnaPANCAN250 (SRGAP3)',
#  'loss:cnaPANCAN251',
#  'loss:cnaPANCAN252',
#  'loss:cnaPANCAN253',
#  'loss:cnaPANCAN254',
#  'loss:cnaPANCAN255',
#  'loss:cnaPANCAN256 (CACNA1D,WNT5A)',
#  'loss:cnaPANCAN257',
#  'loss:cnaPANCAN258',
#  'loss:cnaPANCAN259',
#  'loss:cnaPANCAN260',
#  'loss:cnaPANCAN261',
#  'loss:cnaPANCAN262 (FOXP1)',
#  'loss:cnaPANCAN263',
#  'loss:cnaPANCAN264',
#  'loss:cnaPANCAN266',
#  'gain:cnaPANCAN268',
#  'gain:cnaPANCAN271 (NOTCH2)',
#  'gain:cnaPANCAN273',
#  'gain:cnaPANCAN275 (SDHC)',
#  'gain:cnaPANCAN280 (ARID4B,FH)',
#  'loss:cnaPANCAN281 (RPL22)',
#  'loss:cnaPANCAN292',
#  'loss:cnaPANCAN293',
#  'loss:cnaPANCAN294',
#  'loss:cnaPANCAN296',
#  'gain:cnaPANCAN302 (CLTC,PPM1D)',
#  'gain:cnaPANCAN303',
#  'loss:cnaPANCAN304',
#  'loss:cnaPANCAN305',
#  'loss:cnaPANCAN306',
#  'loss:cnaPANCAN307 (CHD3,GPS2,TP53)',
#  'loss:cnaPANCAN308',
#  'loss:cnaPANCAN309',
#  'loss:cnaPANCAN310 (MAP2K4)',
#  'loss:cnaPANCAN311',
#  'loss:cnaPANCAN312',
#  'loss:cnaPANCAN313',
#  'loss:cnaPANCAN314',
#  'loss:cnaPANCAN315 (NF1,SUZ12)',
#  'loss:cnaPANCAN326 (SOX9)',
#  'gain:cnaPANCAN330 (RPGR)',
#  'loss:cnaPANCAN334',
#  'loss:cnaPANCAN335',
#  'loss:cnaPANCAN336',
#  'loss:cnaPANCAN337',
#  'loss:cnaPANCAN338',
#  'loss:cnaPANCAN339 (ATRX)',
#  'loss:cnaPANCAN340',
#  'loss:cnaPANCAN341',
#  'loss:cnaPANCAN342',
#  'loss:cnaPANCAN343',
#  'gain:cnaPANCAN352 (PMS1)',
#  'loss:cnaPANCAN356 (ERCC3)',
#  'loss:cnaPANCAN360',
#  'loss:cnaPANCAN361',
#  'gain:cnaPANCAN362 (CRNKL1,FOXA2)',
#  'gain:cnaPANCAN363 (ASXL1)',
#  'gain:cnaPANCAN364 (STK4)',
#  'gain:cnaPANCAN365',
#  'gain:cnaPANCAN366',
#  'gain:cnaPANCAN367 (ARFGAP1,GNAS)',
#  'loss:cnaPANCAN368',
#  'loss:cnaPANCAN369',
#  'loss:cnaPANCAN371',
#  'gain:cnaPANCAN374',
#  'gain:cnaPANCAN375',
#  'gain:cnaPANCAN376',
#  'loss:cnaPANCAN377',
#  'loss:cnaPANCAN378 (ZNRF3)',
#  'loss:cnaPANCAN379',
#  'loss:cnaPANCAN380',
#  'loss:cnaPANCAN381 (ARFGAP3)',
#  'gain:cnaPANCAN383',
#  'gain:cnaPANCAN384 (ERCC5,ING1,IRS2,TFDP1)',
#  'loss:cnaPANCAN385 (PABPC3,SACS,ZMYM2)',
#  'loss:cnaPANCAN386',
#  'loss:cnaPANCAN387',
#  'loss:cnaPANCAN388',
#  'loss:cnaPANCAN389 (RB1)',
#  'loss:cnaPANCAN390',
#  'loss:cnaPANCAN391 (ING1,IRS2,TFDP1)',
#  'gain:cnaPANCAN394 (GNG2,SOS2)',
#  'loss:cnaPANCAN396',
#  'loss:cnaPANCAN397',
#  'loss:cnaPANCAN398',
#  'loss:cnaPANCAN399',
#  'loss:cnaPANCAN400',
#  'loss:cnaPANCAN401',
#  'loss:cnaPANCAN402',
#  'loss:cnaPANCAN403',
#  'loss:cnaPANCAN404',
#  'loss:cnaPANCAN405',
#  'loss:cnaPANCAN406',
#  'loss:cnaPANCAN407',
#  'loss:cnaPANCAN408',
#  'loss:cnaPANCAN409',
#  'loss:cnaPANCAN410',
#  'gain:cnaPANCAN411 (BLM,CRTC3,FANCI,IDH2,NR2F2,PCSK6)',
#  'loss:cnaPANCAN412',
#  'loss:cnaPANCAN413',
#  'loss:cnaPANCAN414',
#  'loss:cnaPANCAN415 (B2M,BUB1B,MGA,TP53BP1)',
#  'loss:cnaPANCAN416',
#  'loss:cnaPANCAN417',
#  'loss:cnaPANCAN418',
#  'loss:cnaPANCAN419',
#  'loss:cnaPANCAN420',
#  'loss:cnaPANCAN424',
#  'loss:cnaPANCAN425',
#  'chr1:40782220-40783145(COL9A2)_HypMET',
#  'chr10:93392667-93393147(PPP1R3C)_HypMET',
#  'chr12:124246524-124247254(DNAH10)_HypMET',
#  'chr14:24457864-24458100(DHRS4L2)_HypMET',
#  'chr15:30685087-30685891(CHRFAM7A)_HypMET',
#  'chr15:81426499-81426702(C15orf26)_HypMET',
#  'chr15:93198374-93199181(FAM174B)_HypMET',
#  'chr17:44656490-44657494(ARL17A)_HypMET',
#  'chr17:46691520-46692097(HOXB8)_HypMET',
#  'chr18:77905297-77905566(LOC100130522)_HypMET',
#  'chr19:21265164-21265433(ZNF714)_HypMET',
#  'chr19:49315545-49315765(BCAT2)_HypMET',
#  'chr2:183731819-183732093(FRZB)_HypMET',
#  'chr22:19746924-19747141(TBX1)_HypMET',
#  'chr22:24372912-24373725(LOC391322)_HypMET',
#  'chr22:24384134-24384405(GSTT1)_HypMET',
#  'chr6:291948-292839(DUSP22)_HypMET',
#  'chr8:95652455-95652873(ESRP1)_HypMET',
#  'complexity',
#  'Cl',
#  'rotatable_bond_count',
#  'S',
#  'xlogp',
#  'molecular_weight',
#  'surface_area',
#  'h_bond_acceptor_count',
#  'heavy_atom_count',
#  'bond_stereo_count',
#  'F',
#  '2bonds']

# %%
#List_Names_Melanoma[14]
#np.where(df_Feature_Names_Melanoma=="BRAF_mut")
#np.where(df_Feature_Names_Melanoma=="loss:cnaPANCAN65")
np.where(df_Feature_Names_Melanoma=="BRAF_mut")
#np.where(df_Feature_Names_Melanoma=="loss:cnaPANCAN30 (LARP4B)")
# Out:
# (array([18]), array([1]))

# %%
which_MOGPmodel = "m233_Delta_e-1"  #best: m440; second-best: m34
N = 345
Pfeatures = df_Feature_Names_Melanoma.shape[0]
#df_melanoma = pd.read_csv(_FOLDER+name_for_KLrelevance)
#df_KLRelevance_Mtx = pd.read_csv(_FOLDER+'Relevance_KL_HPC_Melanoma.txt', names=["col"+str(i) for i in range(df_train_No_MolecForm.shape[0]+1)])
df_KLRelevance_Mtx_MOGP = pd.read_csv(_FOLDER+'Best_Model_MelanomaGDSC2_GPy_ExactMOGP/Relevance_MelanomaGDSC2_ExactMOGP_'+which_MOGPmodel+'.txt', names=["col"+str(i) for i in range(N+1)])
#df_KLRelevance_Mtx = pd.read_csv(_FOLDER+'Best_Model_Melanoma_SOGP_IC50/Relevance_Melanoma_SOGP_IC50.txt', names=["col"+str(i) for i in range(N+1)])

df_sorted_MOGP = df_KLRelevance_Mtx_MOGP.sort_values(by=['col0'])
KL_Relevance_MOGP = df_sorted_MOGP.values
KL_Relevance_MOGP = KL_Relevance_MOGP[:,1:].T  #We getrid of first index position
print(KL_Relevance_MOGP.shape)
KL_p_MOGP = np.mean(KL_Relevance_MOGP,0)
plt.figure(figsize = (15,8))
plt.bar(np.arange(0,Pfeatures),KL_p_MOGP/KL_p_MOGP.max())
#plt.plot(np.arange(0,Pfeatures),KL_p_MOGP/KL_p_MOGP.max(),'x')

df_KLR_With_Column_Names_MOGP = pd.DataFrame(KL_p_MOGP[None,:]/KL_p_MOGP.max(), columns=List_Names_Melanoma)
df_KL_Col_Names_Sorted_MOGP = df_KLR_With_Column_Names_MOGP.sort_values(by= 0,axis=1,ascending = False)
# Out:
# (345, 419)

# %%
#np.mean(KL_Relevance_MOGP,0)
#df_sorted_MOGP
#df_KLRelevance_Mtx_MOGP
#df_KLRelevance_Mtx
#df_sorted_MOGP["col0"].values == np.arange(0,419)
#df_sorted_MOGP["col0"].values
#check_pos
# check_pos = np.arange(0,419)
# for i in range(419):
#     if df_sorted_MOGP["col0"].values[i]==check_pos[i]: 
#         print(i)

# %%
#df_KLRelevance_Mtx
#df_sorted
#df_sorted.values.shape
df_KLR_With_Column_Names_MOGP[df_KLR_With_Column_Names_MOGP.columns[0:19]]
# Out:
#    AFF4_mut  AHCTF1_mut  AKAP9_mut  ANK3_mut   APC_mut  ARFGAP3_mut  \
# 0  0.123139    0.109546    0.10843  0.137015  0.130836     0.110248
#
#    ARHGAP29_mut  ARID1A_mut  ARID1B_mut  ARID2_mut  ARID4A_mut  ASPM_mut  \
# 0      0.110248    0.177203    0.123139   0.365486    0.165227  0.167618
#
#    ASXL2_mut   ATM_mut  B2M_mut  BAP1_mut  BAZ2B_mut  BPTF_mut  BRAF_mut
# 0   0.167618  0.170144  0.10843  0.114783   0.133618  0.128644       1.0

# %%
#Top 30 most important features out of 826 features
df_KL_Col_Names_Sorted_MOGP[df_KL_Col_Names_Sorted_MOGP.columns[0:30]].min()
# Out:
# BRAF_mut                                        1.000000
# NRAS_mut                                        0.713648
# h_bond_acceptor_count                           0.598424
# surface_area                                    0.595815
# complexity                                      0.562294
# chr17:46691520-46692097(HOXB8)_HypMET           0.545593
# CDKN2A_mut                                      0.527708
# rotatable_bond_count                            0.522895
# S                                               0.522895
# bond_stereo_count                               0.522895
# F                                               0.522895
# chr10:93392667-93393147(PPP1R3C)_HypMET         0.493349
# molecular_weight                                0.471842
# PLCB1_mut                                       0.462766
# loss:cnaPANCAN81                                0.451694
# loss:cnaPANCAN82                                0.451694
# xlogp                                           0.437457
# loss:cnaPANCAN144 (BNC2,CDKN2A,JAK2,PSIP1)      0.403739
# chr19:49315545-49315765(BCAT2)_HypMET           0.398339
# chr6:291948-292839(DUSP22)_HypMET               0.376180
# 2bonds                                          0.371444
# ARID2_mut                                       0.365486
# chr15:93198374-93199181(FAM174B)_HypMET         0.355109
# ZFHX3_mut                                       0.352531
# FGFR2_mut                                       0.343669
# EP300_mut                                       0.343669
# gain:cnaPANCAN130 (RHEB)                        0.329210
# loss:cnaPANCAN92                                0.327039
# heavy_atom_count                                0.323256
# chr18:77905297-77905566(LOC100130522)_HypMET    0.322081
# dtype: float64

# %%
#Top 30 least important features out of 826 features
df_KL_Col_Names_Sorted_MOGP[df_KL_Col_Names_Sorted_MOGP.columns[-30:]].min()
# Out:
# MAP3K4_mut                       0.109315
# loss:cnaPANCAN294                0.109189
# loss:cnaPANCAN368                0.108852
# loss:cnaPANCAN263                0.108852
# gain:cnaPANCAN108 (CHD9,CYLD)    0.108834
# AKAP9_mut                        0.108430
# B2M_mut                          0.108430
# loss:cnaPANCAN147                0.108430
# loss:cnaPANCAN266                0.107609
# loss:cnaPANCAN403                0.106961
# loss:cnaPANCAN222                0.106961
# loss:cnaPANCAN397                0.106961
# loss:cnaPANCAN223                0.106961
# loss:cnaPANCAN224                0.106961
# loss:cnaPANCAN402                0.106961
# loss:cnaPANCAN400                0.106961
# loss:cnaPANCAN404                0.106961
# loss:cnaPANCAN221                0.106961
# loss:cnaPANCAN172                0.106961
# loss:cnaPANCAN314                0.106961
# loss:cnaPANCAN68                 0.106961
# loss:cnaPANCAN396                0.106961
# loss:cnaPANCAN220 (HIST1H3B)     0.106961
# loss:cnaPANCAN219                0.106961
# loss:cnaPANCAN218                0.106961
# loss:cnaPANCAN217                0.106961
# loss:cnaPANCAN64                 0.106961
# loss:cnaPANCAN399                0.106961
# loss:cnaPANCAN65                 0.106961
# loss:cnaPANCAN398                0.106961
# dtype: float64

# %% [markdown]
# ### Check for BRAF ranking position

# %%
np.where(df_KL_Col_Names_Sorted_MOGP.columns=="BRAF_mut")
# Out:
# (array([0]),)

# %% [markdown]
# # Analysis for SOGP when training over IC50

# %%
which_model = "m3_Delta_e-5"   #best: m3; second-best: mXX
N = 345
Pfeatures = df_Feature_Names_Melanoma.shape[0]
#df_melanoma = pd.read_csv(_FOLDER+name_for_KLrelevance)
#df_KLRelevance_Mtx = pd.read_csv(_FOLDER+'Relevance_KL_HPC_Melanoma.txt', names=["col"+str(i) for i in range(df_train_No_MolecForm.shape[0]+1)])
#df_KLRelevance_Mtx = pd.read_csv(_FOLDER+'Best_Model_MelanomaGDSC2_SOGP_IC50/Relevance_MelanomaGDSC2_SOGP_IC50.txt', names=["col"+str(i) for i in range(N+1)])
df_KLRelevance_Mtx = pd.read_csv(_FOLDER+'Best_Model_MelanomaGDSC2_GPy_SOGP_IC50/Relevance_MelanomaGDSC2_SOGP_IC50_'+which_model+'.txt', names=["col"+str(i) for i in range(N+1)])

df_sorted = df_KLRelevance_Mtx.sort_values(by=['col0'])
KL_Relevance = df_sorted.values
KL_Relevance = KL_Relevance[:,1:].T  #We getrid of first index position
print(KL_Relevance.shape)
KL_p = np.mean(KL_Relevance,0)
plt.figure(figsize = (15,8))
plt.bar(np.arange(0,Pfeatures),KL_p/KL_p.max())

df_KLR_With_Column_Names = pd.DataFrame(KL_p[None,:]/KL_p.max(), columns=List_Names_Melanoma)
df_KL_Col_Names_Sorted = df_KLR_With_Column_Names.sort_values(by= 0,axis=1,ascending = False)
# Out:
# (345, 419)

# %%
#Pfeatures
#KL_p/KL_p.max()
#df_sorted
#df_sorted
#df_KLRelevance_Mtx
#df_sorted["col0"].values == np.arange(0,419)
#df_sorted["col0"].values
# check_pos = np.arange(0,419)
# for i in range(419):
#     if df_sorted["col0"].values[i]==check_pos[i]: 
#         print(i)

# %%
#df_KLRelevance_Mtx
#df_sorted
#df_sorted.values.shape
df_KLR_With_Column_Names[df_KLR_With_Column_Names.columns[0:19]]
# Out:
#    AFF4_mut  AHCTF1_mut  AKAP9_mut  ANK3_mut  APC_mut  ARFGAP3_mut  \
# 0  0.066411    0.042899   0.021692  0.124961  0.04401     0.079601
#
#    ARHGAP29_mut  ARID1A_mut  ARID1B_mut  ARID2_mut  ARID4A_mut  ASPM_mut  \
# 0      0.079601    0.169578    0.066411   0.383955    0.173125  0.130726
#
#    ASXL2_mut   ATM_mut   B2M_mut  BAP1_mut  BAZ2B_mut  BPTF_mut  BRAF_mut
# 0   0.130726  0.199468  0.021692  0.018339   0.097957  0.091634       1.0

# %%
#Top 30 most important features out of 419 features
df_KL_Col_Names_Sorted[df_KL_Col_Names_Sorted.columns[0:32]].min()
# Out:
# BRAF_mut                                      1.000000
# bond_stereo_count                             0.712680
# rotatable_bond_count                          0.712680
# F                                             0.712680
# S                                             0.712680
# NRAS_mut                                      0.710147
# chr17:46691520-46692097(HOXB8)_HypMET         0.648979
# surface_area                                  0.645993
# h_bond_acceptor_count                         0.645208
# chr10:93392667-93393147(PPP1R3C)_HypMET       0.605594
# loss:cnaPANCAN82                              0.570428
# loss:cnaPANCAN81                              0.570428
# CDKN2A_mut                                    0.568784
# complexity                                    0.538977
# chr22:24384134-24384405(GSTT1)_HypMET         0.536291
# PLCB1_mut                                     0.528668
# loss:cnaPANCAN144 (BNC2,CDKN2A,JAK2,PSIP1)    0.524488
# gain:cnaPANCAN123                             0.501090
# loss:cnaPANCAN92                              0.499260
# gain:cnaPANCAN214                             0.495560
# ZFHX3_mut                                     0.480597
# chr19:49315545-49315765(BCAT2)_HypMET         0.459896
# chr6:291948-292839(DUSP22)_HypMET             0.454277
# gain:cnaPANCAN122 (AHR,HDAC9)                 0.450727
# EP300_mut                                     0.433351
# FGFR2_mut                                     0.433351
# loss:cnaPANCAN62 (HRAS,IRF7)                  0.432302
# gain:cnaPANCAN121 (ACTB,CARD11,PMS2,RAC1)     0.424147
# gain:cnaPANCAN130 (RHEB)                      0.410868
# gain:cnaPANCAN330 (RPGR)                      0.407841
# molecular_weight                              0.399125
# loss:cnaPANCAN341                             0.391797
# dtype: float64

# %%
#Top 30 least important features out of 385 features
df_KL_Col_Names_Sorted[df_KL_Col_Names_Sorted.columns[-50:]].min()
# Out:
# loss:cnaPANCAN66                 0.033436
# loss:cnaPANCAN67                 0.033436
# loss:cnaPANCAN195                0.033436
# loss:cnaPANCAN194 (FGFR3)        0.033436
# loss:cnaPANCAN193                0.033436
# loss:cnaPANCAN174                0.033436
# loss:cnaPANCAN173                0.033436
# loss:cnaPANCAN171                0.033436
# loss:cnaPANCAN199                0.033436
# loss:cnaPANCAN200                0.033436
# loss:cnaPANCAN201                0.033436
# loss:cnaPANCAN70                 0.033436
# loss:cnaPANCAN63                 0.033436
# loss:cnaPANCAN263                0.030468
# loss:cnaPANCAN368                0.030452
# loss:cnaPANCAN110                0.030108
# loss:cnaPANCAN202                0.026106
# loss:cnaPANCAN225                0.024052
# loss:cnaPANCAN226                0.024052
# loss:cnaPANCAN147                0.021692
# AKAP9_mut                        0.021692
# B2M_mut                          0.021692
# loss:cnaPANCAN313                0.021325
# loss:cnaPANCAN118 (ZFHX3)        0.020965
# loss:cnaPANCAN119                0.020965
# loss:cnaPANCAN116                0.018339
# BAP1_mut                         0.018339
# gain:cnaPANCAN394 (GNG2,SOS2)    0.016857
# loss:cnaPANCAN101                0.016857
# loss:cnaPANCAN400                0.007563
# loss:cnaPANCAN399                0.007563
# loss:cnaPANCAN314                0.007563
# loss:cnaPANCAN402                0.007553
# loss:cnaPANCAN404                0.007553
# loss:cnaPANCAN396                0.007553
# loss:cnaPANCAN397                0.007553
# loss:cnaPANCAN403                0.007553
# loss:cnaPANCAN64                 0.007511
# loss:cnaPANCAN222                0.007511
# loss:cnaPANCAN223                0.007511
# loss:cnaPANCAN224                0.007511
# loss:cnaPANCAN217                0.007511
# loss:cnaPANCAN220 (HIST1H3B)     0.007511
# loss:cnaPANCAN172                0.007511
# loss:cnaPANCAN219                0.007511
# loss:cnaPANCAN218                0.007511
# loss:cnaPANCAN65                 0.007511
# loss:cnaPANCAN221                0.007511
# loss:cnaPANCAN68                 0.007210
# loss:cnaPANCAN398                0.007209
# dtype: float64

# %% [markdown]
# ### Check for BRAF ranking position for SOGP_IC50

# %%
np.where(df_KL_Col_Names_Sorted.columns=="BRAF_mut")
# Out:
# (array([0]),)

# %%
List_Names_Melanoma
# Out:
# ['AFF4_mut',
#  'AHCTF1_mut',
#  'AKAP9_mut',
#  'ANK3_mut',
#  'APC_mut',
#  'ARFGAP3_mut',
#  'ARHGAP29_mut',
#  'ARID1A_mut',
#  'ARID1B_mut',
#  'ARID2_mut',
#  'ARID4A_mut',
#  'ASPM_mut',
#  'ASXL2_mut',
#  'ATM_mut',
#  'B2M_mut',
#  'BAP1_mut',
#  'BAZ2B_mut',
#  'BPTF_mut',
#  'BRAF_mut',
#  'BRCA2_mut',
#  'BRWD1_mut',
#  'CDC27_mut',
#  'CDKN2A_mut',
#  'CEP290_mut',
#  'CHEK2_mut',
#  'CLASP2_mut',
#  'CLSPN_mut',
#  'CREBBP_mut',
#  'CTCF_mut',
#  'CTNNB1_mut',
#  'CUL2_mut',
#  'CUX1_mut',
#  'DHX15_mut',
#  'ELF1_mut',
#  'EP300_mut',
#  'EZH2_mut',
#  'FAM123B_mut',
#  'FGFR2_mut',
#  'GNA11_mut',
#  'HDAC9_mut',
#  'HRAS_mut',
#  'INPP4A_mut',
#  'INPPL1_mut',
#  'KDM6A_mut',
#  'LAMA2_mut',
#  'LPHN2_mut',
#  'LRP6_mut',
#  'MACF1_mut',
#  'MAGI2_mut',
#  'MAP2K1_mut',
#  'MAP3K4_mut',
#  'MCM8_mut',
#  'MECOM_mut',
#  'MGA_mut',
#  'MLL2_mut',
#  'MLL3_mut',
#  'MYH11_mut',
#  'MYH14_mut',
#  'MYH9_mut',
#  'NCOR1_mut',
#  'NF1_mut',
#  'NRAS_mut',
#  'PABPC3_mut',
#  'PCDH18_mut',
#  'PHLPP1_mut',
#  'PIK3R1_mut',
#  'PLCB1_mut',
#  'PLXNA1_mut',
#  'PSIP1_mut',
#  'PTEN_mut',
#  'RAC1_mut',
#  'RB1_mut',
#  'ROBO2_mut',
#  'RPL5_mut',
#  'SEC31A_mut',
#  'SETD2_mut',
#  'SMARCA1_mut',
#  'SMARCA4_mut',
#  'SOS2_mut',
#  'SRGAP1_mut',
#  'STAG1_mut',
#  'STAG2_mut',
#  'STIP1_mut',
#  'STK11_mut',
#  'TAF1_mut',
#  'TAOK1_mut',
#  'TP53_mut',
#  'TSC1_mut',
#  'WHSC1_mut',
#  'WHSC1L1_mut',
#  'WT1_mut',
#  'ZFHX3_mut',
#  'ZMYM2_mut',
#  'ZNF292_mut',
#  'ZNF638_mut',
#  'gain:cnaPANCAN1 (CCNE1)',
#  'loss:cnaPANCAN2 (STK11)',
#  'loss:cnaPANCAN6',
#  'loss:cnaPANCAN8',
#  'loss:cnaPANCAN15',
#  'gain:cnaPANCAN18',
#  'loss:cnaPANCAN20',
#  'loss:cnaPANCAN21',
#  'loss:cnaPANCAN22',
#  'loss:cnaPANCAN23 (SMAD4)',
#  'loss:cnaPANCAN24',
#  'loss:cnaPANCAN25',
#  'loss:cnaPANCAN26',
#  'gain:cnaPANCAN28 (CUL2,EPC1)',
#  'loss:cnaPANCAN30 (LARP4B)',
#  'loss:cnaPANCAN31',
#  'loss:cnaPANCAN32',
#  'loss:cnaPANCAN33',
#  'loss:cnaPANCAN34',
#  'loss:cnaPANCAN35 (CUL2)',
#  'loss:cnaPANCAN36 (RET)',
#  'loss:cnaPANCAN37',
#  'loss:cnaPANCAN38',
#  'loss:cnaPANCAN39',
#  'loss:cnaPANCAN40',
#  'loss:cnaPANCAN41',
#  'loss:cnaPANCAN42 (ANK3)',
#  'loss:cnaPANCAN43',
#  'loss:cnaPANCAN44 (BMPR1A,FAS,PTEN)',
#  'loss:cnaPANCAN45',
#  'loss:cnaPANCAN46',
#  'loss:cnaPANCAN47',
#  'loss:cnaPANCAN48',
#  'loss:cnaPANCAN49',
#  'loss:cnaPANCAN50',
#  'loss:cnaPANCAN51',
#  'loss:cnaPANCAN52',
#  'loss:cnaPANCAN53',
#  'loss:cnaPANCAN54',
#  'loss:cnaPANCAN55',
#  'gain:cnaPANCAN57 (CAT)',
#  'gain:cnaPANCAN58',
#  'gain:cnaPANCAN59 (CCND1,CTTN)',
#  'gain:cnaPANCAN60',
#  'gain:cnaPANCAN61',
#  'loss:cnaPANCAN62 (HRAS,IRF7)',
#  'loss:cnaPANCAN63',
#  'loss:cnaPANCAN64',
#  'loss:cnaPANCAN65',
#  'loss:cnaPANCAN66',
#  'loss:cnaPANCAN67',
#  'loss:cnaPANCAN68',
#  'loss:cnaPANCAN69',
#  'loss:cnaPANCAN70',
#  'loss:cnaPANCAN71 (EXT2)',
#  'loss:cnaPANCAN72',
#  'loss:cnaPANCAN73',
#  'loss:cnaPANCAN74',
#  'loss:cnaPANCAN75 (MED17)',
#  'loss:cnaPANCAN76',
#  'loss:cnaPANCAN77 (CASP1)',
#  'loss:cnaPANCAN78 (CASP1)',
#  'loss:cnaPANCAN79',
#  'loss:cnaPANCAN80 (SDHD)',
#  'loss:cnaPANCAN81',
#  'loss:cnaPANCAN82',
#  'gain:cnaPANCAN84 (FGFR1,WHSC1L1)',
#  'gain:cnaPANCAN89 (RAD21)',
#  'gain:cnaPANCAN90',
#  'gain:cnaPANCAN91 (MYC)',
#  'loss:cnaPANCAN92',
#  'loss:cnaPANCAN93',
#  'loss:cnaPANCAN94',
#  'loss:cnaPANCAN95',
#  'loss:cnaPANCAN96',
#  'loss:cnaPANCAN97',
#  'loss:cnaPANCAN98',
#  'loss:cnaPANCAN99 (SOX17)',
#  'loss:cnaPANCAN101',
#  'gain:cnaPANCAN108 (CHD9,CYLD)',
#  'loss:cnaPANCAN110',
#  'loss:cnaPANCAN113',
#  'loss:cnaPANCAN116',
#  'loss:cnaPANCAN117 (CHD9,CNOT1,CYLD,MMP2,NUP93)',
#  'loss:cnaPANCAN118 (ZFHX3)',
#  'loss:cnaPANCAN119',
#  'loss:cnaPANCAN120',
#  'gain:cnaPANCAN121 (ACTB,CARD11,PMS2,RAC1)',
#  'gain:cnaPANCAN122 (AHR,HDAC9)',
#  'gain:cnaPANCAN123',
#  'gain:cnaPANCAN124 (EGFR)',
#  'gain:cnaPANCAN125',
#  'gain:cnaPANCAN126',
#  'gain:cnaPANCAN127 (AKAP9)',
#  'gain:cnaPANCAN128',
#  'gain:cnaPANCAN129 (MET)',
#  'gain:cnaPANCAN130 (RHEB)',
#  'loss:cnaPANCAN137 (POT1)',
#  'loss:cnaPANCAN144 (BNC2,CDKN2A,JAK2,PSIP1)',
#  'loss:cnaPANCAN145 (FANCG,PAX5)',
#  'loss:cnaPANCAN146 (GNAQ,NTRK2,PCSK5,TJP2)',
#  'loss:cnaPANCAN147',
#  'loss:cnaPANCAN148',
#  'loss:cnaPANCAN149',
#  'loss:cnaPANCAN150 (PTGS1)',
#  'loss:cnaPANCAN151',
#  'loss:cnaPANCAN152',
#  'loss:cnaPANCAN153 (ABL1)',
#  'loss:cnaPANCAN154',
#  'loss:cnaPANCAN155',
#  'loss:cnaPANCAN156',
#  'loss:cnaPANCAN157',
#  'loss:cnaPANCAN158',
#  'loss:cnaPANCAN159',
#  'loss:cnaPANCAN160',
#  'loss:cnaPANCAN161 (NOTCH1)',
#  'loss:cnaPANCAN162',
#  'gain:cnaPANCAN163 (CHD4,WNK1)',
#  'gain:cnaPANCAN164 (KRAS)',
#  'gain:cnaPANCAN165 (CDK4)',
#  'gain:cnaPANCAN166 (MDM2,NUP107,SRGAP1)',
#  'loss:cnaPANCAN167',
#  'loss:cnaPANCAN168',
#  'loss:cnaPANCAN169',
#  'loss:cnaPANCAN170',
#  'loss:cnaPANCAN171',
#  'loss:cnaPANCAN172',
#  'loss:cnaPANCAN173',
#  'loss:cnaPANCAN174',
#  'loss:cnaPANCAN175',
#  'gain:cnaPANCAN176 (CCT5,TERT,TRIO)',
#  'gain:cnaPANCAN177 (IL7R)',
#  'gain:cnaPANCAN178',
#  'loss:cnaPANCAN181',
#  'gain:cnaPANCAN190 (FGFR3,WHSC1)',
#  'loss:cnaPANCAN193',
#  'loss:cnaPANCAN194 (FGFR3)',
#  'loss:cnaPANCAN195',
#  'loss:cnaPANCAN196',
#  'loss:cnaPANCAN197',
#  'loss:cnaPANCAN198',
#  'loss:cnaPANCAN199',
#  'loss:cnaPANCAN200',
#  'loss:cnaPANCAN201',
#  'loss:cnaPANCAN202',
#  'loss:cnaPANCAN203',
#  'loss:cnaPANCAN204',
#  'loss:cnaPANCAN205',
#  'loss:cnaPANCAN206',
#  'loss:cnaPANCAN207',
#  'loss:cnaPANCAN208 (PCDH18)',
#  'loss:cnaPANCAN209',
#  'loss:cnaPANCAN210 (FAT1,IRF2)',
#  'gain:cnaPANCAN211',
#  'gain:cnaPANCAN214',
#  'loss:cnaPANCAN217',
#  'loss:cnaPANCAN218',
#  'loss:cnaPANCAN219',
#  'loss:cnaPANCAN220 (HIST1H3B)',
#  'loss:cnaPANCAN221',
#  'loss:cnaPANCAN222',
#  'loss:cnaPANCAN223',
#  'loss:cnaPANCAN224',
#  'loss:cnaPANCAN225',
#  'loss:cnaPANCAN226',
#  'loss:cnaPANCAN227',
#  'loss:cnaPANCAN228',
#  'loss:cnaPANCAN229',
#  'loss:cnaPANCAN230 (SYNCRIP,ZNF292)',
#  'loss:cnaPANCAN231',
#  'loss:cnaPANCAN232',
#  'loss:cnaPANCAN233',
#  'loss:cnaPANCAN234',
#  'loss:cnaPANCAN235 (ARID1B,MAP3K4,MLLT4)',
#  'gain:cnaPANCAN239 (FOXP1,MITF)',
#  'gain:cnaPANCAN240',
#  'gain:cnaPANCAN241 (NCK1,STAG1)',
#  'gain:cnaPANCAN242 (PIK3CB)',
#  'gain:cnaPANCAN243',
#  'gain:cnaPANCAN244',
#  'gain:cnaPANCAN245 (MECOM)',
#  'gain:cnaPANCAN246 (SOX2)',
#  'gain:cnaPANCAN247',
#  'gain:cnaPANCAN248 (EIF4A2,RFC4)',
#  'loss:cnaPANCAN250 (SRGAP3)',
#  'loss:cnaPANCAN251',
#  'loss:cnaPANCAN252',
#  'loss:cnaPANCAN253',
#  'loss:cnaPANCAN254',
#  'loss:cnaPANCAN255',
#  'loss:cnaPANCAN256 (CACNA1D,WNT5A)',
#  'loss:cnaPANCAN257',
#  'loss:cnaPANCAN258',
#  'loss:cnaPANCAN259',
#  'loss:cnaPANCAN260',
#  'loss:cnaPANCAN261',
#  'loss:cnaPANCAN262 (FOXP1)',
#  'loss:cnaPANCAN263',
#  'loss:cnaPANCAN264',
#  'loss:cnaPANCAN266',
#  'gain:cnaPANCAN268',
#  'gain:cnaPANCAN271 (NOTCH2)',
#  'gain:cnaPANCAN273',
#  'gain:cnaPANCAN275 (SDHC)',
#  'gain:cnaPANCAN280 (ARID4B,FH)',
#  'loss:cnaPANCAN281 (RPL22)',
#  'loss:cnaPANCAN292',
#  'loss:cnaPANCAN293',
#  'loss:cnaPANCAN294',
#  'loss:cnaPANCAN296',
#  'gain:cnaPANCAN302 (CLTC,PPM1D)',
#  'gain:cnaPANCAN303',
#  'loss:cnaPANCAN304',
#  'loss:cnaPANCAN305',
#  'loss:cnaPANCAN306',
#  'loss:cnaPANCAN307 (CHD3,GPS2,TP53)',
#  'loss:cnaPANCAN308',
#  'loss:cnaPANCAN309',
#  'loss:cnaPANCAN310 (MAP2K4)',
#  'loss:cnaPANCAN311',
#  'loss:cnaPANCAN312',
#  'loss:cnaPANCAN313',
#  'loss:cnaPANCAN314',
#  'loss:cnaPANCAN315 (NF1,SUZ12)',
#  'loss:cnaPANCAN326 (SOX9)',
#  'gain:cnaPANCAN330 (RPGR)',
#  'loss:cnaPANCAN334',
#  'loss:cnaPANCAN335',
#  'loss:cnaPANCAN336',
#  'loss:cnaPANCAN337',
#  'loss:cnaPANCAN338',
#  'loss:cnaPANCAN339 (ATRX)',
#  'loss:cnaPANCAN340',
#  'loss:cnaPANCAN341',
#  'loss:cnaPANCAN342',
#  'loss:cnaPANCAN343',
#  'gain:cnaPANCAN352 (PMS1)',
#  'loss:cnaPANCAN356 (ERCC3)',
#  'loss:cnaPANCAN360',
#  'loss:cnaPANCAN361',
#  'gain:cnaPANCAN362 (CRNKL1,FOXA2)',
#  'gain:cnaPANCAN363 (ASXL1)',
#  'gain:cnaPANCAN364 (STK4)',
#  'gain:cnaPANCAN365',
#  'gain:cnaPANCAN366',
#  'gain:cnaPANCAN367 (ARFGAP1,GNAS)',
#  'loss:cnaPANCAN368',
#  'loss:cnaPANCAN369',
#  'loss:cnaPANCAN371',
#  'gain:cnaPANCAN374',
#  'gain:cnaPANCAN375',
#  'gain:cnaPANCAN376',
#  'loss:cnaPANCAN377',
#  'loss:cnaPANCAN378 (ZNRF3)',
#  'loss:cnaPANCAN379',
#  'loss:cnaPANCAN380',
#  'loss:cnaPANCAN381 (ARFGAP3)',
#  'gain:cnaPANCAN383',
#  'gain:cnaPANCAN384 (ERCC5,ING1,IRS2,TFDP1)',
#  'loss:cnaPANCAN385 (PABPC3,SACS,ZMYM2)',
#  'loss:cnaPANCAN386',
#  'loss:cnaPANCAN387',
#  'loss:cnaPANCAN388',
#  'loss:cnaPANCAN389 (RB1)',
#  'loss:cnaPANCAN390',
#  'loss:cnaPANCAN391 (ING1,IRS2,TFDP1)',
#  'gain:cnaPANCAN394 (GNG2,SOS2)',
#  'loss:cnaPANCAN396',
#  'loss:cnaPANCAN397',
#  'loss:cnaPANCAN398',
#  'loss:cnaPANCAN399',
#  'loss:cnaPANCAN400',
#  'loss:cnaPANCAN401',
#  'loss:cnaPANCAN402',
#  'loss:cnaPANCAN403',
#  'loss:cnaPANCAN404',
#  'loss:cnaPANCAN405',
#  'loss:cnaPANCAN406',
#  'loss:cnaPANCAN407',
#  'loss:cnaPANCAN408',
#  'loss:cnaPANCAN409',
#  'loss:cnaPANCAN410',
#  'gain:cnaPANCAN411 (BLM,CRTC3,FANCI,IDH2,NR2F2,PCSK6)',
#  'loss:cnaPANCAN412',
#  'loss:cnaPANCAN413',
#  'loss:cnaPANCAN414',
#  'loss:cnaPANCAN415 (B2M,BUB1B,MGA,TP53BP1)',
#  'loss:cnaPANCAN416',
#  'loss:cnaPANCAN417',
#  'loss:cnaPANCAN418',
#  'loss:cnaPANCAN419',
#  'loss:cnaPANCAN420',
#  'loss:cnaPANCAN424',
#  'loss:cnaPANCAN425',
#  'chr1:40782220-40783145(COL9A2)_HypMET',
#  'chr10:93392667-93393147(PPP1R3C)_HypMET',
#  'chr12:124246524-124247254(DNAH10)_HypMET',
#  'chr14:24457864-24458100(DHRS4L2)_HypMET',
#  'chr15:30685087-30685891(CHRFAM7A)_HypMET',
#  'chr15:81426499-81426702(C15orf26)_HypMET',
#  'chr15:93198374-93199181(FAM174B)_HypMET',
#  'chr17:44656490-44657494(ARL17A)_HypMET',
#  'chr17:46691520-46692097(HOXB8)_HypMET',
#  'chr18:77905297-77905566(LOC100130522)_HypMET',
#  'chr19:21265164-21265433(ZNF714)_HypMET',
#  'chr19:49315545-49315765(BCAT2)_HypMET',
#  'chr2:183731819-183732093(FRZB)_HypMET',
#  'chr22:19746924-19747141(TBX1)_HypMET',
#  'chr22:24372912-24373725(LOC391322)_HypMET',
#  'chr22:24384134-24384405(GSTT1)_HypMET',
#  'chr6:291948-292839(DUSP22)_HypMET',
#  'chr8:95652455-95652873(ESRP1)_HypMET',
#  'complexity',
#  'Cl',
#  'rotatable_bond_count',
#  'S',
#  'xlogp',
#  'molecular_weight',
#  'surface_area',
#  'h_bond_acceptor_count',
#  'heavy_atom_count',
#  'bond_stereo_count',
#  'F',
#  '2bonds']
